# %% [markdown]
# <a href="https://colab.research.google.com/github/pedsrc/data_science/blob/master/Violence_analysis_in_Rio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img alt="Colaboratory logo" width="15%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
# #### **Data Science na Prática 2.0**
# *by [sigmoidal.ai](https://sigmoidal.ai)*
#
# ---

# %% [markdown]
# # Violence analysis in Rio de Janeiro
#
# Rio de janeiro is the second biggest city in Brazil, and draws attention to it's attractions such as Christ the Redeemer, Sugarloaf, and Copacabana.
# Despites Rio de Janeiro is the most sought touristic destination in Brazil, the violence in Rio it's overwhelming.
# The drugs trafficking, thiefts, and deaths are increasing during the years.
# Rio is starting to be as amazing as horrifying.

# %% [markdown]
# ## Data acquisition
#
# The open data are avaiable by the government of Rio de Janeiro Intitute of Public Security [ISP](http://www.ispdados.rj.gov.br/estatistica.html), they make avaiable as weel an [iterative dashboard](http://www.ispvisualizacao.rj.gov.br/index.html) with easy data visualization.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/carlosfab/dsnp2/master/datasets/violencia_rio.csv")

# %% [markdown]
# ## Inicial data analysis
#
# In this part we will see how the data are structured, change and study then to make powerfull insights.
#
# **Variable Dictionary**
#
# * `vano`- Year of the incidence
# * `mes` - Mounth of the incidence
# * `hom_doloso` - Knavish homicide
# * `lesao_corp_morte` - Body damage followed by death
# * `latrocinio` - Theft followed by death
# * `hom_por_interv_policial` - Homicide by police intervention
# * `tentat_hom` - Homicide attempt
# * `lesao_corp_dolosa` - Malicious body damage
# * `estupro` - Rape
# * `hom_culposo` - Negligent homicide
# * `lesao_corp_culposa` - Negligent body damage
# * `roubo_comercio` - Commerce theft
# * `roubo_residencia` - Home theft
# * `roubo_veiculo` - Vehicle theft
# * `roubo_carga` - Cargo theft
# * `roubo_transeunte` - Passer-by theft
# * `roubo_em_coletivo` - Colletive theft
# * `roubo_banco` - Bank theft
# * `roubo_cx_eletronico` - Cash machine theft
# * `roubo_celular` - Cell phone theft
# * `roubo_conducao_saque` - Theft during money withdrawal
# * `roubo_apos_saque` - Theft after money withdrawal
# * `roubo_bicicleta` - Bike theft
# * `outros_roubos` - Other theft
# * `total_roubos` - Total theft
# * `furto_veiculos` - Vehicle steal
# * `furto_transeunte` - Passer-by steal
# * `furto_coletivo` - Colletive steal
# * `furto_celular` - Cell phone steal
# * `furto_bicicleta` - Bike steal
# * `outros_furtos` - Other steal
# * `total_furtos` - Total steal
# * `sequestros` -  Kidnapping
# * `extorsao` - Extortion
# * `sequestro_relampago` -  Express kidnapping
# * `estelionato` -   Larceny
# * `apreensao_drogas` -   Drug seizures
# * `posse_drogas` - Possession of drugs
# * `trafico_drogas` - Drug trafficking
# * `apreensao_drogas_sem_autor` - Drug seizure without holder
# * `recuperacao_veiculos` -   Vehicle recovery
# * `apf` - Arrested act
# * `aaapai` - Teenager arrest act by infraction act
# * `cmp` - Served time in prision
# * `cmba` - Served arest and seek warrent
# * `ameaca` - Threat
# * `pessoas_desaparecidas` - Missing people
# * `encontro_cadaver` - Body finding
# * `encontro_ossada` - Bone finding
# * `pol_militares_mortos_serv` - Military Police officer death in duty
# * `pol_civis_mortos_serv` -   Civil Police officer death in duty
# * `indicador_letalidade` - Lethality
# * `indicador_roubo_rua` - Street robbery
# * `indicador_roubo_veic` - Vehicle robbery
# * `registro_ocorrencias` - Incident record

# %% [markdown]
# The first step is to very our dataframe shape.

# %%
df.shape
# Out:
# (344, 56)

# %% [markdown]
# It's interesting to see as well what columns do we have to work.

# %%
df.columns
# Out:
# Index(['vano', 'mes', 'hom_doloso', 'lesao_corp_morte', 'latrocinio',
#        'hom_por_interv_policial', 'tentat_hom', 'lesao_corp_dolosa', 'estupro',
#        'hom_culposo', 'lesao_corp_culposa', 'roubo_comercio',
#        'roubo_residencia', 'roubo_veiculo', 'roubo_carga', 'roubo_transeunte',
#        'roubo_em_coletivo', 'roubo_banco', 'roubo_cx_eletronico',
#        'roubo_celular', 'roubo_conducao_saque', 'roubo_apos_saque',
#        'roubo_bicicleta', 'outros_roubos', 'total_roubos', 'furto_veiculos',
#        'furto_transeunte', 'furto_coletivo', 'furto_celular',
#        'furto_bicicleta', 'outros_furtos', 'total_furtos', 'sequestro',
#        'extorsao', 'sequestro_relampago', 'estelionato', 'apreensao_drogas',
#        'posse_drogas', 'trafico_drogas', 'apreensao_drogas_sem_autor',
#        'recuperacao_veiculos', 'apf', 'aaapai', 'cmp', 'cmba', 'ameaca',
#        'pessoas_desaparecidas', 'encontro_cadaver', 'encontro_ossada',
# ...

# %% [markdown]
# And verify too the type of data we are working with.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 56 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   vano                        344 non-null    int64
#  1   mes                         344 non-null    int64
#  2   hom_doloso                  344 non-null    int64
#  3   lesao_corp_morte            248 non-null    float64
#  4   latrocinio                  344 non-null    int64
#  5   hom_por_interv_policial     260 non-null    float64
#  6   tentat_hom                  344 non-null    int64
#  7   lesao_corp_dolosa           344 non-null    int64
#  8   estupro                     200 non-null    float64
#  9   hom_culposo                 260 non-null    float64
#  10  lesao_corp_culposa          248 non-null    float64
#  11  roubo_comercio              344 non-null    int64
#  12  roubo_residencia            344 non-null    int64
# ...

# %% [markdown]
# After start to make our analysis it's important to see our dataset, with the five inicial entries.

# %%
df.head()
# Out:
#    vano  mes  hom_doloso  ...  indicador_roubo_veic  registro_ocorrencias  fase
# 0  1991    1         657  ...                  1174                   NaN     3
# 1  1991    2         732  ...                  1097                   NaN     3
# 2  1991    3         713  ...                  1265                   NaN     3
# 3  1991    4         634  ...                  1415                   NaN     3
# 4  1991    5         650  ...                  1449                   NaN     3
#
# [5 rows x 56 columns]

# %% [markdown]
# Another important information it's to very the percent of null values.

# %%
df.isnull().sum() / df.shape[0]
# Out:
# vano                          0.000000
# mes                           0.000000
# hom_doloso                    0.000000
# lesao_corp_morte              0.279070
# latrocinio                    0.000000
# hom_por_interv_policial       0.244186
# tentat_hom                    0.000000
# lesao_corp_dolosa             0.000000
# estupro                       0.418605
# hom_culposo                   0.244186
# lesao_corp_culposa            0.279070
# roubo_comercio                0.000000
# roubo_residencia              0.000000
# roubo_veiculo                 0.000000
# roubo_carga                   0.000000
# roubo_transeunte              0.000000
# roubo_em_coletivo             0.000000
# roubo_banco                   0.000000
# roubo_cx_eletronico           0.418605
# roubo_celular                 0.313953
# roubo_conducao_saque          0.418605
# roubo_apos_saque              0.418605
# roubo_bicicleta               0.802326
# outros_roubos                 0.000000
# ...

# %% [markdown]
# ## Statistical Violence Information in Rio de Janeiro

# %% [markdown]
# The statistical overview it's very important to seek if we have some information that are damaged our analysis (outliers), and to see the beginning of ours analysis and what we can extract from it.

# %%
df.describe()
# Out:
#               vano         mes  ...  registro_ocorrencias        fase
# count   344.000000  344.000000  ...            248.000000  344.000000
# mean   2004.837209    6.453488  ...          53794.161290    2.994186
# std       8.289036    3.447759  ...          11039.051992    0.076138
# min    1991.000000    1.000000  ...          30621.000000    2.000000
# 25%    1998.000000    3.000000  ...          45374.500000    3.000000
# 50%    2005.000000    6.000000  ...          54926.500000    3.000000
# 75%    2012.000000    9.000000  ...          63292.500000    3.000000
# max    2019.000000   12.000000  ...          75403.000000    3.000000
#
# [8 rows x 56 columns]

# %% [markdown]
# One interesting analise it's teh percent of recovered vehicle in the total that was lost (theft/steal), in this analise we can view the effectiveness of the police department.
#
#   * $\frac{\text{recovered vehicles}}{\text{vehicles theft} + \text{vehicles steal}}$

# %%
roubo_veiculos = df.roubo_veiculo.mean()
furto_veiculos = df.furto_veiculos.mean()
recuperacao_veiculos = df.recuperacao_veiculos.mean()
print(roubo_veiculos)
print(furto_veiculos)
print(recuperacao_veiculos)
# Out:
# 2448.6976744186045
# 1674.671511627907
# 1772.2383720930231

# %%
carros_recuperados = recuperacao_veiculos / (roubo_veiculos + furto_veiculos)
carros_recuperados
# Out:
# 0.42980346705075084

# %% [markdown]
# See how it's the maximum and minimum numbers of murder we have per mounth it's important to see how the violence vary during the time, we will plot a graphic in the next topic to have a better insight.

# %%
dol_min = df.hom_doloso.min()
dol_max = df.hom_doloso.max()
print(dol_min)
print(dol_max)
# Out:
# 272
# 831

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# As told before, we prepared all data to extract the better information to show, some insights have been collect and some are very shocking.
#
# The first one is a murder histogram.

# %%
df.hom_doloso.plot.hist();

# %% [markdown]
# In this graphic, we can see how the colletive thefts have been incressing during time.

# %%
df.roubo_em_coletivo.plot.line();

# %% [markdown]
# And the last one it's a comparison of rape and missing people during time.

# %%
df.estupro.plot(kind="line");
df.pessoas_desaparecidas.plot(kind="line");

# %% [markdown]
# ## Conclusion
#
# To conclude, we can see that the violence in Rio is still alarming.
#
# The percert of recovered vehicles are 42%.
#
# The higher frequency of murder per month are between 500 to 600 deaths.
#
# The colletive thefts are increasing.
#
# And the curver of rape and missing people are very similar, so we can say that many people that are missing was raped.
